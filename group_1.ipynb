# %% [markdown]
# <a href="https://colab.research.google.com/github/DLShrankhala/LSTMModelForFloodDetection-/blob/main/group_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
from sklearn.preprocessing import MinMaxScaler as MM
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error as MSE, mean_absolute_error as MAE, r2_score
import numpy as np

# %%
class Data :

    def __init__(self) :
        self.dataframe = pd.DataFrame([])

    #Read data from CSV dataset(s)
    def read(self, filename : str) :
        """Reads values/data from CSV files into dataframe"""
        if os.path.exists(filename) :
            self.dataframe = pd.read_csv(filename, skiprows = 1)
            #
            print(f"Data successfully read from {filename}.")
        else :
            print(f"Error: The file {filename} does not exist.")

    #Check for null values in the dataset(s)
    def check_null_values(self) :
        """Checks for null values in the dataframe."""
        print("Null Values Before Cleaning:")
        print(self.dataframe.isnull().sum())

    #Cleaning the dataset :
    def clean_dataset(self) :
        """Cleans the dataset by removing null values"""
        if self.dataframe is not None :
            original_shape = self.dataframe.shape #store the original shape of the DataFrame
            self.dataframe = self.dataframe.dropna() #drop all rows with null values; dropna() is a Pandas method that, by default, drops all rows that contain at least one null value.
            cleaned_shape = self.dataframe.shape #store the cleaned shape of DataFrame
            print(f"Dataset cleaned. Original shape: {original_shape}, Cleaned shape: {cleaned_shape}.")
        else:
            print("Error: No data to clean. Please read a dataset first.")


    # Normalize the data
    def normalize(self):
        """Normalizes numeric columns in the dataframe"""
        # Select columns to scale
        columns_to_scale = ['ACTUAL (mm)']

        # Strip trailing spaces from DataFrame column names
        self.dataframe.columns = self.dataframe.columns.str.strip()

        # Ensure all specified columns are in the DataFrame
        columns_to_scale = [col for col in columns_to_scale if col in self.dataframe.columns]

        if columns_to_scale:
            # Select the data to scale
            data_to_scale = self.dataframe[columns_to_scale]

            # Initialize the MinMaxScaler
            self.scaler = MM()

            # Fit and transform the data
            scaled_data = self.scaler.fit_transform(data_to_scale)

            # Update the DataFrame with the scaled data
            self.dataframe[columns_to_scale] = scaled_data

            print("Data successfully normalized:")
            print(self.dataframe.head())
        else:
            print("Error: No columns to normalize. Please ensure the dataframe contains the necessary columns.")


    def visualize_normal(self) :
      """Plot graph for NORMAL (mm) stock values v/s dates"""
      if 'Dates' in self.dataframe.columns and 'NORMAL (mm)' in self.dataframe.columns:
            self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'])
            plt.figure(figsize = (14, 7))
            plt.plot(self.dataframe['Dates'], self.dataframe['NORMAL (mm)'], label = 'NORMAL (mm)')
            plt.title('NORMAL (mm) rainfall over time')
            plt.xlabel('Dates')
            plt.ylabel('NORMAL (mm) rainfall')
            plt.legend()
            plt.show()
      else:
        print("Dates and/or NORMAL (mm) column not found in the dataframe")

    def visualize_actual(self) :
        """Plot graph for ACTUAL (mm) stock values v/s dates"""
        if 'Dates' in self.dataframe.columns and 'ACTUAL (mm)' in self.dataframe.columns :
            self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'])
            plt.figure(figsize = (18, 10))
            plt.plot(self.dataframe['Dates'], self.dataframe['ACTUAL (mm)'], label = 'ACTUAL (mm)')
            plt.title('ACTUAL (mm) rainfall over time')
            plt.xlabel('Dates')
            plt.ylabel('ACTUAL (mm) rainfall')
            plt.legend()
            plt.show()

    def print_head(self):
        """Prints the head of the dataframe."""
        print("Head of the DataFrame:")
        print(self.dataframe.head())

    def print_description(self):
        """Prints the description of the dataframe."""
        print("\nDescription of the DataFrame:")
        print(self.dataframe.describe())

# %%
data = Data()

# %%
data.read('/content/Darjeeling_daily_10y.csv')
# Out:
# Data successfully read from /content/Darjeeling_daily_10y.csv.

# %%
data.check_null_values()
# Out:
# Null Values Before Cleaning:
# Dates           0
# NORMAL (mm)     0
# ACTUAL (mm)     0
# dtype: int64

# %%
data.print_head()
data.print_description()
# Out:
# Head of the DataFrame:
#          Dates  NORMAL (mm)   ACTUAL (mm)
# 0  18-Mar-2014           0.9          0.00
# 1  19-Mar-2014           1.3          2.59
# 2  20-Mar-2014           1.4          2.81
# 3  21-Mar-2014           2.0          4.88
# 4  22-Mar-2014           1.0          0.17
#
# Description of the DataFrame:
#        NORMAL (mm)   ACTUAL (mm)
# count   3617.000000   3617.000000
# mean       7.374509      9.417982
# std        8.586096     18.815402
# min        0.000000      0.000000
# 25%        0.500000      0.000000
# 50%        2.800000      0.690000
# 75%       14.400000     11.120000
# max       32.700000    230.430000

# %%
data.clean_dataset()
# Out:
# Dataset cleaned. Original shape: (3617, 3), Cleaned shape: (3617, 3).

# %%
data.check_null_values()
# Out:
# Null Values Before Cleaning:
# Dates           0
# NORMAL (mm)     0
# ACTUAL (mm)     0
# dtype: int64

# %%
data.print_head()
data.print_description()
# Out:
# Head of the DataFrame:
#          Dates  NORMAL (mm)   ACTUAL (mm)
# 0  18-Mar-2014           0.9          0.00
# 1  19-Mar-2014           1.3          2.59
# 2  20-Mar-2014           1.4          2.81
# 3  21-Mar-2014           2.0          4.88
# 4  22-Mar-2014           1.0          0.17
#
# Description of the DataFrame:
#        NORMAL (mm)   ACTUAL (mm)
# count   3617.000000   3617.000000
# mean       7.374509      9.417982
# std        8.586096     18.815402
# min        0.000000      0.000000
# 25%        0.500000      0.000000
# 50%        2.800000      0.690000
# 75%       14.400000     11.120000
# max       32.700000    230.430000

# %%
data.normalize()
# Out:
# Data successfully normalized:
#          Dates  NORMAL (mm)  ACTUAL (mm)
# 0  18-Mar-2014          0.9     0.000000
# 1  19-Mar-2014          1.3     0.011240
# 2  20-Mar-2014          1.4     0.012195
# 3  21-Mar-2014          2.0     0.021178
# 4  22-Mar-2014          1.0     0.000738

# %%
data.visualize_normal()

# %%
data.visualize_actual()

# %%
from tensorflow.keras.models import Sequential as sq
from tensorflow.keras.layers import LSTM, Dense
from keras.optimizers import RMSprop, Nadam, Adam, SGD
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error as MSE, mean_absolute_error as MAE, r2_score, mean_absolute_percentage_error as MAPE
from sklearn.preprocessing import MinMaxScaler as MM
import matplotlib.pyplot as plt

# %%
class model_train_lstm_weather :

    def __init__(self, dataframe, scaler) :
        self.dataframe = dataframe
        self.scaler = scaler

    def prep_data_weather(self, feature_col = 'ACTUAL (mm)', look_back = 60) :   #"look back" refers to the number of previous time steps that the model uses to make predictions for the next time step.
        """Prepare data for LSTM by creating sequences"""
        data = self.dataframe[feature_col].values     # Extract the feature column values
        data = data.reshape(-1, 1)  # Reshape to (n_samples, 1)
        X, y = [], []
        for i in range(len(data) - look_back):
            X.append(data[i:i + look_back])     # Append sequences of length 'look_back'
            y.append(data[i + look_back])       # Append the next value as the target
        X, y = np.array(X), np.array(y)
        # Split data while preserving the number of features
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = False)
        return X_train, X_test, y_train, y_test.reshape(-1, 1)

    def build_train_lstm(self, feature_col = 'ACTUAL (mm)', look_back = 60, epochs = 200, batch_size = 32) :
        """Build and train the LSTM model"""
        X_train, X_test, y_train, y_test = self.prep_data_weather(feature_col, look_back)

        self.X_train = X_train  # Save the training features
        self.y_train = y_train  # Save the training targets

        model = sq()    # Initialize the model
        model.add(LSTM(units = 50, return_sequences = True, input_shape = (look_back, 1)))
        model.add(LSTM(units = 50))   #this layer does not have return_sequences=True, which means it will only return the final output of the sequence, not the full sequence.
        model.add(Dense(1))     #This is the output layer of the model. Since we are predicting a single value (the next day's stock price), this layer has one neuron.

        #LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)) adds an LSTM layer to the model.
        #50 is the number of units in this LSTM layer, which means the layer will have 50 LSTM cells.
        #return_sequences=True means this layer will return the full sequence of outputs for each input sequence, not just the final output. This is necessary because we are stacking another LSTM layer on top.
        #input_shape = (X_train.shape[1], 1) specifies the shape of the input data for this layer.
        #X_train.shape[1] is the number of time steps (look-back period), and 1 is the number of features (since we are using just one feature, the stock price).

        nadam = Nadam(learning_rate = 0.002)
        model.compile(optimizer = nadam, loss = 'mean_squared_error')     # Compile the model using Adam optimizer and mean squared error loss

        # Train the model with the training data
        self.history = model.fit(self.X_train, self.y_train, epochs = epochs, batch_size = batch_size, validation_data = (X_test, y_test))

        plt.plot(self.history.history['loss'])
        plt.plot(self.history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc = 'upper right')
        plt.show()

        self.model = model    # Save the trained model
        self.X_test = X_test  # Save the test features
        self.y_test = y_test  # Save the test targets



    def predict_plot(self) :
        """Make predictions and plot the results"""
        predictions = self.model.predict(self.X_test)   # Predict the test data
        predictions = predictions.reshape(-1, 1)    # Reshape the predictions

        # Extract the 'NORMAL (mm)' column from the original dataframe
        self.normal_scaler = MM(feature_range = (0, 1))  # Create a new scaler for just the 'ACTUAL (mm)' column
        self.normal_scaler.fit(self.dataframe['ACTUAL (mm)'].values.reshape(-1, 1))  # Fit the scaler to the 'ACTUAL (mm)' column

        # Inverse transform predictions using the scaler fitted on 'ACTUAL (mm)' column
        predictions = self.normal_scaler.inverse_transform(predictions)
        # Inverse transform actual 'ACTUAL (mm)' values
        actual = self.normal_scaler.inverse_transform(self.y_test)

        plt.figure(figsize = (18, 10))
        plt.plot(actual, label = 'ACTUAL rainfall val.')
        plt.plot(predictions, label = 'Predicted ACTUAL rainfall val.')
        plt.title('Actual vs Predicted ACTUAL rainfall val.')
        plt.xlabel('Dates')
        plt.ylabel('ACTUAL rainfall val.')
        plt.legend()
        plt.show()


    def evaluate_model(self):
        """Calculates and prints evaluation metrics."""
        predictions = self.model.predict(self.X_test)   # Predict the test data
        predictions = self.normal_scaler.inverse_transform(predictions)    # Inverse transform predictions
        actual = self.normal_scaler.inverse_transform(self.y_test)      # Inverse transform actual values

        mse = MSE(actual, predictions)
        rmse = np.sqrt(mse)
        mae = MAE(actual, predictions)


        # Calculate MAPE with handling for zeros in actual values
        mask = actual != 0
        mape = np.mean(np.abs((actual[mask] - predictions[mask]) / actual[mask])) * 100 if np.any(mask) else np.nan

        print(f"Mean Squared Error (MSE): {mse}")
        print(f"Root Mean Squared Error (RMSE): {rmse}")
        print(f"Mean Absolute Error (MAE): {mae}")
        #print(f"R-squared (R2): {r2}")

# %%
trainer = model_train_lstm_weather(data.dataframe, data.scaler)

# %%
trainer.build_train_lstm()
# Out:
# Epoch 1/200
# 89/89 [==============================] - 12s 72ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 2/200
# 89/89 [==============================] - 10s 113ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 3/200
# 89/89 [==============================] - 10s 116ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 4/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 5/200
# 89/89 [==============================] - 8s 86ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 6/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 7/200
# 89/89 [==============================] - 7s 73ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 8/200
# 89/89 [==============================] - 6s 69ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 9/200
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 10/200
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 11/200
# 89/89 [==============================] - 8s 93ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 12/200
# 89/89 [==============================] - 9s 96ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 13/200
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 14/200
# 89/89 [==============================] - 5s 60ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 15/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 16/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 17/200
# 89/89 [==============================] - 6s 73ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 18/200
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 19/200
# 89/89 [==============================] - 12s 133ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 20/200
# 89/89 [==============================] - 5s 60ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 21/200
# 89/89 [==============================] - 8s 87ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 22/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 23/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 24/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 25/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 26/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 27/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 28/200
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 29/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 30/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 31/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 32/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 33/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 34/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 35/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 36/200
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 37/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 38/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 39/200
# 89/89 [==============================] - 6s 71ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 40/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 41/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 42/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 43/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 44/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 45/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 46/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 47/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 48/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 49/200
# 89/89 [==============================] - 6s 69ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 50/200
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 51/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 52/200
# 89/89 [==============================] - 8s 88ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 53/200
# 89/89 [==============================] - 5s 62ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 54/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 55/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 56/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 57/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 58/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 59/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 60/200
# 89/89 [==============================] - 6s 68ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 61/200
# 89/89 [==============================] - 7s 73ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 62/200
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 63/200
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 64/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 65/200
# 89/89 [==============================] - 7s 84ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 66/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 67/200
# 89/89 [==============================] - 7s 83ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 68/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 69/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 70/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0045 - val_loss: 0.0039
# Epoch 71/200
# 89/89 [==============================] - 8s 86ms/step - loss: 0.0045 - val_loss: 0.0039
# Epoch 72/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 73/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 74/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 75/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 76/200
# 89/89 [==============================] - 7s 73ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 77/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 78/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 79/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 80/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 81/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 82/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 83/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 84/200
# 89/89 [==============================] - 7s 78ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 85/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 86/200
# 89/89 [==============================] - 6s 71ms/step - loss: 0.0043 - val_loss: 0.0058
# Epoch 87/200
# 89/89 [==============================] - 8s 95ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 88/200
# 89/89 [==============================] - 8s 85ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 89/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 90/200
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 91/200
# 89/89 [==============================] - 6s 69ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 92/200
# 89/89 [==============================] - 6s 71ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 93/200
# 89/89 [==============================] - 6s 70ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 94/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 95/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 96/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 97/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 98/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 99/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 100/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 101/200
# 89/89 [==============================] - 7s 78ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 102/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0039 - val_loss: 0.0053
# Epoch 103/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 104/200
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 105/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 106/200
# 89/89 [==============================] - 7s 78ms/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 107/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 108/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 109/200
# 89/89 [==============================] - 6s 71ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 110/200
# 89/89 [==============================] - 8s 85ms/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 111/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0036 - val_loss: 0.0053
# Epoch 112/200
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 113/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 114/200
# 89/89 [==============================] - 7s 83ms/step - loss: 0.0033 - val_loss: 0.0070
# Epoch 115/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 116/200
# 89/89 [==============================] - 6s 73ms/step - loss: 0.0033 - val_loss: 0.0052
# Epoch 117/200
# 89/89 [==============================] - 6s 71ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 118/200
# 89/89 [==============================] - 6s 67ms/step - loss: 0.0032 - val_loss: 0.0058
# Epoch 119/200
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0032 - val_loss: 0.0052
# Epoch 120/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 121/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 122/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 123/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 124/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0031 - val_loss: 0.0050
# Epoch 125/200
# 89/89 [==============================] - 7s 80ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 126/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0029 - val_loss: 0.0053
# Epoch 127/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0029 - val_loss: 0.0053
# Epoch 128/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0027 - val_loss: 0.0056
# Epoch 129/200
# 89/89 [==============================] - 6s 71ms/step - loss: 0.0027 - val_loss: 0.0058
# Epoch 130/200
# 89/89 [==============================] - 6s 72ms/step - loss: 0.0027 - val_loss: 0.0060
# Epoch 131/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 132/200
# 89/89 [==============================] - 7s 78ms/step - loss: 0.0026 - val_loss: 0.0055
# Epoch 133/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0025 - val_loss: 0.0059
# Epoch 134/200
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0025 - val_loss: 0.0061
# Epoch 135/200
# 89/89 [==============================] - 5s 61ms/step - loss: 0.0026 - val_loss: 0.0072
# Epoch 136/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0025 - val_loss: 0.0065
# Epoch 137/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0024 - val_loss: 0.0071
# Epoch 138/200
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0024 - val_loss: 0.0063
# Epoch 139/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0023 - val_loss: 0.0065
# Epoch 140/200
# 89/89 [==============================] - 6s 72ms/step - loss: 0.0022 - val_loss: 0.0065
# Epoch 141/200
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 142/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0024 - val_loss: 0.0064
# Epoch 143/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0022 - val_loss: 0.0061
# Epoch 144/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0021 - val_loss: 0.0065
# Epoch 145/200
# 89/89 [==============================] - 7s 79ms/step - loss: 0.0021 - val_loss: 0.0065
# Epoch 146/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0020 - val_loss: 0.0067
# Epoch 147/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0020 - val_loss: 0.0074
# Epoch 148/200
# 89/89 [==============================] - 6s 62ms/step - loss: 0.0019 - val_loss: 0.0072
# Epoch 149/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0018 - val_loss: 0.0079
# Epoch 150/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0019 - val_loss: 0.0074
# Epoch 151/200
# 89/89 [==============================] - 6s 72ms/step - loss: 0.0018 - val_loss: 0.0067
# Epoch 152/200
# 89/89 [==============================] - 6s 69ms/step - loss: 0.0018 - val_loss: 0.0081
# Epoch 153/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0018 - val_loss: 0.0073
# Epoch 154/200
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0017 - val_loss: 0.0077
# Epoch 155/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0017 - val_loss: 0.0080
# Epoch 156/200
# 89/89 [==============================] - 8s 87ms/step - loss: 0.0017 - val_loss: 0.0081
# Epoch 157/200
# 89/89 [==============================] - 6s 68ms/step - loss: 0.0016 - val_loss: 0.0083
# Epoch 158/200
# 89/89 [==============================] - 7s 84ms/step - loss: 0.0015 - val_loss: 0.0077
# Epoch 159/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0016 - val_loss: 0.0072
# Epoch 160/200
# 89/89 [==============================] - 7s 83ms/step - loss: 0.0015 - val_loss: 0.0081
# Epoch 161/200
# 89/89 [==============================] - 6s 63ms/step - loss: 0.0016 - val_loss: 0.0075
# Epoch 162/200
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0014 - val_loss: 0.0077
# Epoch 163/200
# 89/89 [==============================] - 6s 69ms/step - loss: 0.0013 - val_loss: 0.0079
# Epoch 164/200
# 89/89 [==============================] - 6s 70ms/step - loss: 0.0013 - val_loss: 0.0082
# Epoch 165/200
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0012 - val_loss: 0.0079
# Epoch 166/200
# 89/89 [==============================] - 6s 64ms/step - loss: 0.0011 - val_loss: 0.0085
# Epoch 167/200
# 89/89 [==============================] - 7s 81ms/step - loss: 0.0012 - val_loss: 0.0085
# Epoch 168/200
# 89/89 [==============================] - 6s 65ms/step - loss: 0.0015 - val_loss: 0.0083
# Epoch 169/200
# 89/89 [==============================] - 7s 82ms/step - loss: 0.0013 - val_loss: 0.0091
# Epoch 170/200
# 89/89 [==============================] - 6s 66ms/step - loss: 0.0012 - val_loss: 0.0085
# Epoch 171/200
# 89/89 [==============================] - 7s 84ms/step - loss: 0.0010 - val_loss: 0.0077
# Epoch 172/200
# 89/89 [==============================] - 6s 63ms/step - loss: 9.5412e-04 - val_loss: 0.0081
# Epoch 173/200
# 89/89 [==============================] - 7s 81ms/step - loss: 9.5141e-04 - val_loss: 0.0079
# Epoch 174/200
# 89/89 [==============================] - 6s 65ms/step - loss: 8.7392e-04 - val_loss: 0.0082
# Epoch 175/200
# 89/89 [==============================] - 7s 78ms/step - loss: 8.7313e-04 - val_loss: 0.0082
# Epoch 176/200
# 89/89 [==============================] - 6s 70ms/step - loss: 8.3602e-04 - val_loss: 0.0080
# Epoch 177/200
# 89/89 [==============================] - 6s 71ms/step - loss: 8.7588e-04 - val_loss: 0.0080
# Epoch 178/200
# 89/89 [==============================] - 7s 75ms/step - loss: 8.9473e-04 - val_loss: 0.0072
# Epoch 179/200
# 89/89 [==============================] - 7s 74ms/step - loss: 9.3088e-04 - val_loss: 0.0082
# Epoch 180/200
# 89/89 [==============================] - 7s 80ms/step - loss: 9.3709e-04 - val_loss: 0.0082
# Epoch 181/200
# 89/89 [==============================] - 6s 68ms/step - loss: 8.4778e-04 - val_loss: 0.0080
# Epoch 182/200
# 89/89 [==============================] - 7s 82ms/step - loss: 7.9925e-04 - val_loss: 0.0075
# Epoch 183/200
# 89/89 [==============================] - 6s 71ms/step - loss: 8.0853e-04 - val_loss: 0.0079
# Epoch 184/200
# 89/89 [==============================] - 7s 82ms/step - loss: 7.4970e-04 - val_loss: 0.0084
# Epoch 185/200
# 89/89 [==============================] - 6s 68ms/step - loss: 8.3082e-04 - val_loss: 0.0079
# Epoch 186/200
# 89/89 [==============================] - 7s 83ms/step - loss: 7.6051e-04 - val_loss: 0.0077
# Epoch 187/200
# 89/89 [==============================] - 6s 69ms/step - loss: 6.8801e-04 - val_loss: 0.0073
# Epoch 188/200
# 89/89 [==============================] - 8s 86ms/step - loss: 6.3437e-04 - val_loss: 0.0079
# Epoch 189/200
# 89/89 [==============================] - 6s 64ms/step - loss: 6.4310e-04 - val_loss: 0.0072
# Epoch 190/200
# 89/89 [==============================] - 7s 80ms/step - loss: 6.9319e-04 - val_loss: 0.0078
# Epoch 191/200
# 89/89 [==============================] - 6s 62ms/step - loss: 7.2288e-04 - val_loss: 0.0078
# Epoch 192/200
# 89/89 [==============================] - 7s 80ms/step - loss: 6.4652e-04 - val_loss: 0.0088
# Epoch 193/200
# 89/89 [==============================] - 6s 66ms/step - loss: 6.9205e-04 - val_loss: 0.0077
# Epoch 194/200
# 89/89 [==============================] - 7s 75ms/step - loss: 5.9307e-04 - val_loss: 0.0079
# Epoch 195/200
# 89/89 [==============================] - 6s 70ms/step - loss: 5.6731e-04 - val_loss: 0.0080
# Epoch 196/200
# 89/89 [==============================] - 6s 71ms/step - loss: 5.6596e-04 - val_loss: 0.0078
# Epoch 197/200
# 89/89 [==============================] - 7s 75ms/step - loss: 5.3256e-04 - val_loss: 0.0078
# Epoch 198/200
# 89/89 [==============================] - 6s 67ms/step - loss: 5.2921e-04 - val_loss: 0.0078
# Epoch 199/200
# 89/89 [==============================] - 7s 83ms/step - loss: 5.7270e-04 - val_loss: 0.0075
# Epoch 200/200
# 89/89 [==============================] - 6s 65ms/step - loss: 5.4046e-04 - val_loss: 0.0088

# %%
trainer.predict_plot()
# Out:
# 23/23 [==============================] - 1s 18ms/step

# %%
trainer.evaluate_model()
# Out:
# 23/23 [==============================] - 1s 25ms/step
# Mean Squared Error (MSE): 0.008788195022363617
# Root Mean Squared Error (RMSE): 0.09374537333844064
# Mean Absolute Error (MAE): 0.051536381748371475

# %%
with open('model.pkl','wb') as file:
  pickle.dump(trainer,file)

# %%
with open('model.pkl','rb') as file:
  trained_model = pickle.load(file)

# %%
trained_model.evaluate_model()
# Out:
# 23/23 [==============================] - 3s 17ms/step
# Mean Squared Error (MSE): 0.008788195022363617
# Root Mean Squared Error (RMSE): 0.09374537333844064
# Mean Absolute Error (MAE): 0.051536381748371475
