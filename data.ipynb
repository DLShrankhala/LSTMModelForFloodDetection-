# %%
import imdlib as imd
import pandas as pd
import geopandas as gpd

# %%
path = "/media/shuryanshgupta001/New Volume/Web Scraping/dataset"

start_yr = 2014
end_yr = 2023
variable = 'rain' # other options are ('tmin'/ 'tmax')

imd.get_data(variable, start_yr, end_yr, fn_format='yearwise', file_dir=path)
data = imd.open_data(variable, start_yr, end_yr,'yearwise', path)
ds = data.get_xarray()
print(ds)
# Out:
# Downloading: rain for year 2014
# Downloading: rain for year 2015
# Downloading: rain for year 2016
# Downloading: rain for year 2017
# Downloading: rain for year 2018
# Downloading: rain for year 2019
# Downloading: rain for year 2020
# Downloading: rain for year 2021
# Downloading: rain for year 2022
# Downloading: rain for year 2023
# Download Successful !!!
# <xarray.Dataset> Size: 509MB
# Dimensions:  (time: 3652, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 1kB 6.5 6.75 7.0 7.25 7.5 ... 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 1kB 66.5 66.75 67.0 67.25 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 29kB 2014-01-01 2014-01-02 ... 2023-12-31
# Data variables:
#     rain     (time, lat, lon) float64 509MB -999.0 -999.0 ... -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2024-07-08 14:49:54.832281 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
latLongDistrict_Bihar = [
    [25.5941, 85.1376, 'Patna'],
    [24.7969, 85.0071, 'Gaya'],
    [26.1209, 85.3647, 'Muzaffarpur'],
    [25.2445, 86.9718, 'Bhagalpur'],
    [26.1524, 85.8913, 'Darbhanga'],
    [25.7781, 87.4753, 'Purnia'],
    [25.4207, 86.1285, 'Begusarai'],
    [25.8801, 86.6005, 'Saharsa'],
    [25.5630, 83.9777, 'Buxar'],
    [26.3477, 86.0621, 'Madhubani'],
    [26.1496, 87.4366, 'Araria'],
    [24.7450, 84.3800, 'Aurangabad'],
    [24.8877, 86.9207, 'Banka'],
    [25.4796, 86.9916, 'Begusarai'],
    [25.2445, 86.9718, 'Bhagalpur'],
    [25.3988, 84.2186, 'Bhojpur'],
    [26.6505, 84.9000, 'East Champaran (Motihari)'],
    [26.4670, 84.4400, 'Gopalganj'],
    [24.9000, 86.2000, 'Jamui'],
    [25.1660, 84.9833, 'Jehanabad'],
    [25.1500, 83.6500, 'Kaimur (Bhabua)'],
    [25.5400, 87.5700, 'Katihar'],
    [25.5000, 86.5000, 'Khagaria'],
    [26.0839, 87.9500, 'Kishanganj'],
    [25.1667, 86.0667, 'Lakhisarai'],
    [25.9000, 86.8000, 'Madhepura'],
    [25.3750, 86.4744, 'Munger'],
    [25.2000, 85.5000, 'Nalanda'],
    [24.8833, 85.5333, 'Nawada'],
    [24.9500, 84.0333, 'Rohtas (Sasaram)'],
    [25.8667, 85.7833, 'Samastipur'],
    [25.9167, 84.7833, 'Saran'],
    [25.1333, 85.8500, 'Sheikhpura'],
    [26.5000, 85.3000, 'Sheohar'],
    [26.6000, 85.4833, 'Sitamarhi'],
    [26.2167, 84.3667, 'Siwan'],
    [26.1167, 86.6000, 'Supaul'],
    [25.8667, 85.7500, 'Vaishali'],
    [27.1500, 84.3000, 'West Champaran (Bettiah)']
]

for lat, lon, district_name in latLongDistrict_Bihar:
    # Generate CSV filename with district name
    filename = f"{district_name}.csv"
    
    # Save data to CSV file with district-specific filename
    data.to_csv(filename, lat, lon, path)
    
    print(f"Data saved for {district_name} ({lat}, {lon}) in {filename}")
# Out:
# Data saved for Patna (25.5941, 85.1376) in Patna.csv
# Data saved for Gaya (24.7969, 85.0071) in Gaya.csv
# Data saved for Muzaffarpur (26.1209, 85.3647) in Muzaffarpur.csv
# Data saved for Bhagalpur (25.2445, 86.9718) in Bhagalpur.csv
# Data saved for Darbhanga (26.1524, 85.8913) in Darbhanga.csv
# Data saved for Purnia (25.7781, 87.4753) in Purnia.csv
# Data saved for Begusarai (25.4207, 86.1285) in Begusarai.csv
# Data saved for Saharsa (25.8801, 86.6005) in Saharsa.csv
# Data saved for Buxar (25.563, 83.9777) in Buxar.csv
# Data saved for Madhubani (26.3477, 86.0621) in Madhubani.csv
# Data saved for Araria (26.1496, 87.4366) in Araria.csv
# Data saved for Aurangabad (24.745, 84.38) in Aurangabad.csv
# Data saved for Banka (24.8877, 86.9207) in Banka.csv
# Data saved for Begusarai (25.4796, 86.9916) in Begusarai.csv
# Data saved for Bhagalpur (25.2445, 86.9718) in Bhagalpur.csv
# Data saved for Bhojpur (25.3988, 84.2186) in Bhojpur.csv
# Data saved for East Champaran (Motihari) (26.6505, 84.9) in East Champaran (Motihari).csv
# Data saved for Gopalganj (26.467, 84.44) in Gopalganj.csv
# Data saved for Jamui (24.9, 86.2) in Jamui.csv
# Data saved for Jehanabad (25.166, 84.9833) in Jehanabad.csv
# Data saved for Kaimur (Bhabua) (25.15, 83.65) in Kaimur (Bhabua).csv
# Data saved for Katihar (25.54, 87.57) in Katihar.csv
# Data saved for Khagaria (25.5, 86.5) in Khagaria.csv
# Data saved for Kishanganj (26.0839, 87.95) in Kishanganj.csv
# Data saved for Lakhisarai (25.1667, 86.0667) in Lakhisarai.csv
# Data saved for Madhepura (25.9, 86.8) in Madhepura.csv
# Data saved for Munger (25.375, 86.4744) in Munger.csv
# Data saved for Nalanda (25.2, 85.5) in Nalanda.csv
# Data saved for Nawada (24.8833, 85.5333) in Nawada.csv
# Data saved for Rohtas (Sasaram) (24.95, 84.0333) in Rohtas (Sasaram).csv
# Data saved for Samastipur (25.8667, 85.7833) in Samastipur.csv
# Data saved for Saran (25.9167, 84.7833) in Saran.csv
# Data saved for Sheikhpura (25.1333, 85.85) in Sheikhpura.csv
# Data saved for Sheohar (26.5, 85.3) in Sheohar.csv
# Data saved for Sitamarhi (26.6, 85.4833) in Sitamarhi.csv
# Data saved for Siwan (26.2167, 84.3667) in Siwan.csv
# Data saved for Supaul (26.1167, 86.6) in Supaul.csv
# Data saved for Vaishali (25.8667, 85.75) in Vaishali.csv
# Data saved for West Champaran (Bettiah) (27.15, 84.3) in West Champaran (Bettiah).csv

# %%
latLongDistrict_WestBengal = [
    [26.4835, 89.5229, "Alipurduar"],
    [23.2325, 87.0716, "Bankura"],
    [24.0016, 87.6190, "Birbhum"],
    [26.3248, 89.4411, "Cooch Behar"],
    [25.2445, 88.8384, "Dakshin Dinajpur (South Dinajpur)"],
    [27.0375, 88.2361, "Darjeeling"],
    [22.9052, 88.3768, "Hooghly"],
    [22.5958, 88.2636, "Howrah"],
    [26.5435, 88.7193, "Jalpaiguri"],
    [22.4464, 86.9824, "Jhargram"],
    [27.0705, 88.4727, "Kalimpong"],
    [22.5726, 88.3639, "Kolkata"],
    [25.0119, 88.1450, "Malda"],
    [24.1750, 88.2804, "Murshidabad"],
    [23.4707, 88.5808, "Nadia"],
    [22.5822, 88.3975, "North 24 Parganas"],
    [22.4219, 87.3215, "Paschim Medinipur (West Medinipur)"],
    [21.9342, 87.0165, "Purba Medinipur (East Medinipur)"],
    [23.3315, 86.3631, "Purulia"],
    [22.1416, 88.3215, "South 24 Parganas"],
    [25.6217, 88.1600, "Uttar Dinajpur (North Dinajpur)"],
    [23.6111, 87.2828, "Paschim Bardhaman (West Bardhaman)"],
    [23.2324, 87.8637, "Purba Bardhaman (East Bardhaman)"]
]

for lat, lon, district_name in latLongDistrict_WestBengal:
    filename = f"{district_name}.csv"
    data.to_csv(filename, lat, lon, path)
    print(f"Data saved for {district_name} ({lat}, {lon}) in {filename}")
# Out:
# Data saved for Alipurduar (26.4835, 89.5229) in Alipurduar.csv
# Data saved for Bankura (23.2325, 87.0716) in Bankura.csv
# Data saved for Birbhum (24.0016, 87.619) in Birbhum.csv
# Data saved for Cooch Behar (26.3248, 89.4411) in Cooch Behar.csv
# Data saved for Dakshin Dinajpur (South Dinajpur) (25.2445, 88.8384) in Dakshin Dinajpur (South Dinajpur).csv
# Data saved for Darjeeling (27.0375, 88.2361) in Darjeeling.csv
# Data saved for Hooghly (22.9052, 88.3768) in Hooghly.csv
# Data saved for Howrah (22.5958, 88.2636) in Howrah.csv
# Data saved for Jalpaiguri (26.5435, 88.7193) in Jalpaiguri.csv
# Data saved for Jhargram (22.4464, 86.9824) in Jhargram.csv
# Data saved for Kalimpong (27.0705, 88.4727) in Kalimpong.csv
# Data saved for Kolkata (22.5726, 88.3639) in Kolkata.csv
# Data saved for Malda (25.0119, 88.145) in Malda.csv
# Data saved for Murshidabad (24.175, 88.2804) in Murshidabad.csv
# Data saved for Nadia (23.4707, 88.5808) in Nadia.csv
# Data saved for North 24 Parganas (22.5822, 88.3975) in North 24 Parganas.csv
# Data saved for Paschim Medinipur (West Medinipur) (22.4219, 87.3215) in Paschim Medinipur (West Medinipur).csv
# Data saved for Purba Medinipur (East Medinipur) (21.9342, 87.0165) in Purba Medinipur (East Medinipur).csv
# Data saved for Purulia (23.3315, 86.3631) in Purulia.csv
# Data saved for South 24 Parganas (22.1416, 88.3215) in South 24 Parganas.csv
# Data saved for Uttar Dinajpur (North Dinajpur) (25.6217, 88.16) in Uttar Dinajpur (North Dinajpur).csv
# Data saved for Paschim Bardhaman (West Bardhaman) (23.6111, 87.2828) in Paschim Bardhaman (West Bardhaman).csv
# Data saved for Purba Bardhaman (East Bardhaman) (23.2324, 87.8637) in Purba Bardhaman (East Bardhaman).csv
