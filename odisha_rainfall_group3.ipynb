# %% [markdown]
# ## Weather Forecast (Rainfall) prediction for Odisha Districts (Group - 3)

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler as MM

# %% [markdown]
# ### Data Normalization and visualization

# %%
class Data:
    def __init__(self):
        self.dataframe = pd.DataFrame([])

    def read(self, file_name: str):
        try:
            self.dataframe = pd.read_csv(file_name)
        except FileNotFoundError:
            print(f"File {file_name} not found.")
        except pd.errors.EmptyDataError:
            print("No data found in the file.")
        except Exception as e:
            print(f"An error occurred: {e}")

    def clean_data(self):
        """Remove null values"""
        self.dataframe = self.dataframe.dropna()

    def print_head(self):
        """Print the first few rows of the dataframe"""
        print(self.dataframe.head())
        return self.dataframe

    def print_description(self):
        """Print the statistical description of the dataframe"""
        print(self.dataframe.describe())

    def normalization(self):
        """Normalizes numeric columns in the dataframe"""
        columns_to_scale = ['ACTUAL']

        self.dataframe.columns = self.dataframe.columns.str.strip()

        columns_to_scale = [col for col in columns_to_scale if col in self.dataframe.columns]

        if columns_to_scale:
            data_to_scale = self.dataframe[columns_to_scale]

            self.scaler = MM()

            scaled_data = self.scaler.fit_transform(data_to_scale)

            self.dataframe[columns_to_scale] = scaled_data

            print("Data successfully normalized:")
            print(self.dataframe.head())
        else:
            print("Error: No columns to normalize. Please ensure the dataframe contains the necessary columns.")

    def visualize_NORMAL(self):
        """Plot graph for Normal rainfall v/s date for all districts in a single plot"""
        if 'Dates' in self.dataframe.columns and 'NORMAL' in self.dataframe.columns and 'district' in self.dataframe.columns:
            self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'], format='%d-%b-%Y')

            plt.figure(figsize=(14, 7))

            for district in self.dataframe['district'].unique():
                district_data = self.dataframe[self.dataframe['district'] == district]
                plt.plot(district_data['Dates'], district_data['NORMAL'], label=f'Normal Rainfall - {district}', linestyle='-')

            plt.title('Monthly Rainfall in Districts (NORMAL)')
            plt.xlabel('Date')
            plt.ylabel('Rainfall (mm)')
            plt.legend()
            plt.grid(True)
            plt.xticks(rotation=45)
            plt.show()

        else:
            print("Column(s) not found in the dataframe")


    def visualize_ACTUAL(self):
        """Plot graph for Actual rainfall v/s date for all districts"""
        if 'Dates' in self.dataframe.columns and 'ACTUAL' in self.dataframe.columns and 'district' in self.dataframe.columns:
            self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'], format='%d-%b-%Y')

            plt.figure(figsize=(14, 7))

            for district in self.dataframe['district'].unique():
                district_data = self.dataframe[self.dataframe['district'] == district]
                plt.plot(district_data['Dates'], district_data['ACTUAL'], label=f'Actual Rainfall - {district}', linestyle='-')

            plt.title('Monthly Rainfall in Districts (ACTUAL)')
            plt.xlabel('Date')
            plt.ylabel('Rainfall (mm)')
            plt.legend()
            plt.grid(True)
            plt.xticks(rotation=45)
            plt.show()

        else:
            print("Column(s) not found in the dataframe")

# %%
data = Data()

# %%
data.read('Odisha Rainfall day-wise.csv')

# %%
df = data.print_head()
# Out:
#        Dates  NORMAL    ACTUAL district  Year  Month
# 0 2019-03-01     0.8  0.000778   Anugul  2019      3
# 1 2019-03-02     1.8  0.000000   Anugul  2019      3
# 2 2019-03-03     1.6  0.000000   Anugul  2019      3
# 3 2019-03-04     0.7  0.000188   Anugul  2019      3
# 4 2019-03-05     0.5  0.000349   Anugul  2019      3

# %%
data.print_description()
# Out:
#              NORMAL        ACTUAL
# count  16119.000000  16119.000000
# mean       3.989826      4.200973
# std        4.876777     11.964816
# min        0.000000      0.000000
# 25%        0.400000      0.000000
# 50%        1.500000      0.000000
# 75%        7.000000      3.070000
# max       28.000000    372.530000

# %%
data.normalization()
# Out:
# Data successfully normalized:
#          Dates  NORMAL    ACTUAL district
# 0  01-Mar-2019     0.8  0.000778   Anugul
# 1  02-Mar-2019     1.8  0.000000   Anugul
# 2  03-Mar-2019     1.6  0.000000   Anugul
# 3  04-Mar-2019     0.7  0.000188   Anugul
# 4  05-Mar-2019     0.5  0.000349   Anugul

# %%
data.visualize_NORMAL()

# %%
data.visualize_ACTUAL()

# %% [markdown]
# ### Model Training

# %%
class Training:
    def __init__(self, dataframe, scaler):
        self.dataframe = dataframe
        self.scaler = scaler

    def prepare_lstm_data(self, seq_length=3):
        """Prepare data for LSTM model"""
        self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'])
        self.dataframe['Year'] = self.dataframe['Dates'].dt.year
        self.dataframe['Month'] = self.dataframe['Dates'].dt.month

        features = self.dataframe[['Year', 'Month', 'NORMAL', 'ACTUAL']]
        features_scaled = self.scaler.fit_transform(features)

        def create_sequences(data, seq_length):
            xs, ys = [], []
            for i in range(len(data) - seq_length):
                x = data[i:i + seq_length]
                y = data[i + seq_length][3]
                xs.append(x)
                ys.append(y)
            return np.array(xs), np.array(ys)

        self.X, self.y = create_sequences(features_scaled, seq_length)
        print("Shape of X:", self.X.shape)
        print("Shape of y:", self.y.shape)
        

    def build_lstm_model(self):
        """Build LSTM model"""
        self.model = Sequential()
        self.model.add(LSTM(50, return_sequences=True, input_shape=(self.X.shape[1], self.X.shape[2])))
        self.model.add(LSTM(50, return_sequences=False))
        self.model.add(Dense(25))
        self.model.add(Dense(1))

        self.model.compile(optimizer='adam', loss='mean_squared_error')
        self.model.summary()


    def train_lstm_model(self, epochs=50, batch_size=1):
        """Train LSTM model"""
        train_size = int(len(self.X) * 0.8)
        self.X_train, self.X_test = self.X[:train_size], self.X[train_size:]
        self.y_train, self.y_test = self.y[:train_size], self.y[train_size:]

        self.history = self.model.fit(self.X_train, self.y_train, epochs=epochs, batch_size=batch_size, validation_data=(self.X_test, self.y_test))

        plt.plot(self.history.history['loss'])
        plt.plot(self.history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper right')
        plt.show()


    def evaluate_lstm_model(self):
        """Evaluate LSTM model"""
        y_pred = self.model.predict(self.X_test)

        y_test_scaled = self.scaler.inverse_transform(np.concatenate((np.zeros((self.y_test.shape[0], 3)), self.y_test.reshape(-1, 1)), axis=1))[:, 3]
        y_pred_scaled = self.scaler.inverse_transform(np.concatenate((np.zeros((y_pred.shape[0], 3)), y_pred), axis=1))[:, 3]

        rmse = np.sqrt(np.mean((y_test_scaled - y_pred_scaled) ** 2))
        print('Root Mean Squared Error:', rmse)

        plt.plot(y_test_scaled, label='True Value')
        plt.plot(y_pred_scaled, label='Predicted Value')
        plt.title('Predictions vs True Values')
        plt.xlabel('Time Step')
        plt.ylabel('ACTUAL')
        plt.legend()
        plt.show()

# %%
training = Training(data.dataframe, data.scaler)

# %%
training.prepare_lstm_data(seq_length=3)
# Out:
# Shape of X: (16116, 3, 4)
# Shape of y: (16116,)

# %%
training.build_lstm_model()
# Out:
# WARNING:tensorflow:From c:\Users\habee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\habee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 50)             11000
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 32501 (126.96 KB)
# Trainable params: 32501 (126.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
training.train_lstm_model(epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\habee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 202/202 [==============================] - 6s 10ms/step - loss: 0.0010 - val_loss: 6.5916e-04
# Epoch 2/100
# 202/202 [==============================] - 1s 6ms/step - loss: 9.8230e-04 - val_loss: 6.5660e-04
# Epoch 3/100
# 202/202 [==============================] - 1s 6ms/step - loss: 9.6589e-04 - val_loss: 6.2182e-04
# Epoch 4/100
# 202/202 [==============================] - 1s 5ms/step - loss: 9.3083e-04 - val_loss: 5.9146e-04
# Epoch 5/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.8782e-04 - val_loss: 5.7520e-04
# Epoch 6/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.8056e-04 - val_loss: 5.7392e-04
# Epoch 7/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.8617e-04 - val_loss: 5.6248e-04
# Epoch 8/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.7646e-04 - val_loss: 5.7276e-04
# Epoch 9/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.8006e-04 - val_loss: 5.8629e-04
# Epoch 10/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.6827e-04 - val_loss: 5.6558e-04
# Epoch 11/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.7280e-04 - val_loss: 5.6408e-04
# Epoch 12/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.7508e-04 - val_loss: 5.6368e-04
# Epoch 13/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5848e-04 - val_loss: 5.4794e-04
# Epoch 14/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5693e-04 - val_loss: 5.7605e-04
# Epoch 15/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.5772e-04 - val_loss: 5.5809e-04
# Epoch 16/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5408e-04 - val_loss: 5.5244e-04
# Epoch 17/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5472e-04 - val_loss: 5.4156e-04
# Epoch 18/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5427e-04 - val_loss: 5.5677e-04
# Epoch 19/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5422e-04 - val_loss: 5.4695e-04
# Epoch 20/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5615e-04 - val_loss: 5.4350e-04
# Epoch 21/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5181e-04 - val_loss: 5.4555e-04
# Epoch 22/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4797e-04 - val_loss: 5.4154e-04
# Epoch 23/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4739e-04 - val_loss: 5.4432e-04
# Epoch 24/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4797e-04 - val_loss: 5.6690e-04
# Epoch 25/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.5167e-04 - val_loss: 5.3739e-04
# Epoch 26/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4939e-04 - val_loss: 5.3461e-04
# Epoch 27/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4938e-04 - val_loss: 5.3874e-04
# Epoch 28/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4731e-04 - val_loss: 5.3716e-04
# Epoch 29/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4432e-04 - val_loss: 5.4026e-04
# Epoch 30/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4527e-04 - val_loss: 5.3498e-04
# Epoch 31/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4477e-04 - val_loss: 5.3775e-04
# Epoch 32/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3896e-04 - val_loss: 5.6278e-04
# Epoch 33/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4369e-04 - val_loss: 5.3780e-04
# Epoch 34/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4132e-04 - val_loss: 5.4323e-04
# Epoch 35/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4101e-04 - val_loss: 5.3441e-04
# Epoch 36/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4125e-04 - val_loss: 5.3183e-04
# Epoch 37/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3769e-04 - val_loss: 5.3449e-04
# Epoch 38/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.4002e-04 - val_loss: 5.3897e-04
# Epoch 39/100
# 202/202 [==============================] - 2s 12ms/step - loss: 8.3817e-04 - val_loss: 5.3231e-04
# Epoch 40/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.4265e-04 - val_loss: 5.4105e-04
# Epoch 41/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.3661e-04 - val_loss: 5.3514e-04
# Epoch 42/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.4444e-04 - val_loss: 5.3309e-04
# Epoch 43/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3835e-04 - val_loss: 5.3745e-04
# Epoch 44/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3757e-04 - val_loss: 5.2939e-04
# Epoch 45/100
# 202/202 [==============================] - 3s 13ms/step - loss: 8.3672e-04 - val_loss: 5.3489e-04
# Epoch 46/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.4054e-04 - val_loss: 5.3615e-04
# Epoch 47/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3638e-04 - val_loss: 5.3661e-04
# Epoch 48/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3552e-04 - val_loss: 5.3034e-04
# Epoch 49/100
# 202/202 [==============================] - 3s 13ms/step - loss: 8.3962e-04 - val_loss: 5.3756e-04
# Epoch 50/100
# 202/202 [==============================] - 3s 13ms/step - loss: 8.3505e-04 - val_loss: 5.3467e-04
# Epoch 51/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3162e-04 - val_loss: 5.3418e-04
# Epoch 52/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3346e-04 - val_loss: 5.3355e-04
# Epoch 53/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.3570e-04 - val_loss: 5.3938e-04
# Epoch 54/100
# 202/202 [==============================] - 3s 17ms/step - loss: 8.3825e-04 - val_loss: 5.3539e-04
# Epoch 55/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3154e-04 - val_loss: 5.7501e-04
# Epoch 56/100
# 202/202 [==============================] - 3s 13ms/step - loss: 8.3632e-04 - val_loss: 5.5409e-04
# Epoch 57/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.3351e-04 - val_loss: 5.2798e-04
# Epoch 58/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.2479e-04 - val_loss: 5.3126e-04
# Epoch 59/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3339e-04 - val_loss: 5.3542e-04
# Epoch 60/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2997e-04 - val_loss: 5.4336e-04
# Epoch 61/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3336e-04 - val_loss: 5.3031e-04
# Epoch 62/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3437e-04 - val_loss: 5.3163e-04
# Epoch 63/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.3364e-04 - val_loss: 5.2624e-04
# Epoch 64/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.3161e-04 - val_loss: 5.4362e-04
# Epoch 65/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3414e-04 - val_loss: 5.3590e-04
# Epoch 66/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3244e-04 - val_loss: 5.3444e-04
# Epoch 67/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.3033e-04 - val_loss: 5.3733e-04
# Epoch 68/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2974e-04 - val_loss: 5.3703e-04
# Epoch 69/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2881e-04 - val_loss: 5.3226e-04
# Epoch 70/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.2951e-04 - val_loss: 5.2820e-04
# Epoch 71/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3089e-04 - val_loss: 5.4255e-04
# Epoch 72/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3209e-04 - val_loss: 5.3964e-04
# Epoch 73/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.2849e-04 - val_loss: 5.2893e-04
# Epoch 74/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3002e-04 - val_loss: 5.4541e-04
# Epoch 75/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2724e-04 - val_loss: 5.2952e-04
# Epoch 76/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2766e-04 - val_loss: 5.2553e-04
# Epoch 77/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2869e-04 - val_loss: 5.2649e-04
# Epoch 78/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.3062e-04 - val_loss: 5.3165e-04
# Epoch 79/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2047e-04 - val_loss: 5.3818e-04
# Epoch 80/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2470e-04 - val_loss: 5.2794e-04
# Epoch 81/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2283e-04 - val_loss: 5.4903e-04
# Epoch 82/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2804e-04 - val_loss: 5.3494e-04
# Epoch 83/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2406e-04 - val_loss: 5.3483e-04
# Epoch 84/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2327e-04 - val_loss: 5.4166e-04
# Epoch 85/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2302e-04 - val_loss: 5.3652e-04
# Epoch 86/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2476e-04 - val_loss: 5.4392e-04
# Epoch 87/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2669e-04 - val_loss: 5.3422e-04
# Epoch 88/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2356e-04 - val_loss: 5.3899e-04
# Epoch 89/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2052e-04 - val_loss: 5.3274e-04
# Epoch 90/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2295e-04 - val_loss: 5.3748e-04
# Epoch 91/100
# 202/202 [==============================] - 1s 4ms/step - loss: 8.2335e-04 - val_loss: 5.3850e-04
# Epoch 92/100
# 202/202 [==============================] - 1s 4ms/step - loss: 8.2045e-04 - val_loss: 5.4488e-04
# Epoch 93/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2345e-04 - val_loss: 5.3798e-04
# Epoch 94/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.2226e-04 - val_loss: 5.3211e-04
# Epoch 95/100
# 202/202 [==============================] - 1s 6ms/step - loss: 8.1932e-04 - val_loss: 5.3308e-04
# Epoch 96/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2072e-04 - val_loss: 5.3686e-04
# Epoch 97/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.1918e-04 - val_loss: 5.4027e-04
# Epoch 98/100
# 202/202 [==============================] - 1s 4ms/step - loss: 8.2021e-04 - val_loss: 5.3421e-04
# Epoch 99/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.2746e-04 - val_loss: 5.3683e-04
# Epoch 100/100
# 202/202 [==============================] - 1s 5ms/step - loss: 8.0949e-04 - val_loss: 5.5427e-04

# %%
training.evaluate_lstm_model()
# Out:
# 101/101 [==============================] - 1s 2ms/step
# Root Mean Squared Error: 0.023542968884479556

# %% [markdown]
# ### Save and Load Trained Model

# %%
import pickle

# %%
with open('model.pkl','wb') as file:
  pickle.dump(training,file)

# %%
with open('model.pkl','rb') as file:
  trained_model = pickle.load(file)

# %%
trained_model.evaluate_lstm_model()
# Out:
# 101/101 [==============================] - 1s 2ms/step
# Root Mean Squared Error: 0.023542968884479556
