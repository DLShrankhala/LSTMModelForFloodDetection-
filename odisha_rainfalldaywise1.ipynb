# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
class Data:
    def __init__(self):
        self.dataframe = pd.DataFrame([])

    def read(self, file_name: str):
        try:
            self.dataframe = pd.read_csv(file_name)
        except FileNotFoundError:
            print(f"File {file_name} not found.")
        except pd.errors.EmptyDataError:
            print("No data found in the file.")
        except Exception as e:
            print(f"An error occurred: {e}")

    def clean_data(self):
        """Remove null values"""
        self.dataframe = self.dataframe.dropna()

    def print_head(self):
        """Print the first few rows of the dataframe"""
        print(self.dataframe.head())
        return self.dataframe

    def print_description(self):
        """Print the statistical description of the dataframe"""
        print(self.dataframe.describe())

    def normalization(self):
        """Normalize the data frame, excluding the Date and district columns"""
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        numeric_columns = self.dataframe.select_dtypes(include=['float64', 'int64']).columns
        self.dataframe[numeric_columns] = self.scaler.fit_transform(self.dataframe[numeric_columns])

    def visualize_NORMAL(self):
        """Plot graph for Normal rainfall v/s date for all districts in a single plot"""
        if 'Dates' in self.dataframe.columns and 'NORMAL' in self.dataframe.columns and 'district' in self.dataframe.columns:
            # Update the format string to match the actual date format in your data
            self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'], format='%d-%b-%Y')

            plt.figure(figsize=(14, 7))

            for district in self.dataframe['district'].unique():
                district_data = self.dataframe[self.dataframe['district'] == district]
                plt.plot(district_data['Dates'], district_data['NORMAL'], label=f'Normal Rainfall - {district}', linestyle='-')

            plt.title('Monthly Rainfall in Districts (NORMAL)')
            plt.xlabel('Date')
            plt.ylabel('Rainfall (mm)')
            plt.legend()
            plt.grid(True)
            plt.xticks(rotation=45)
            plt.show()

        else:
            print("Column(s) not found in the dataframe")


    def visualize_ACTUAL(self):
        """Plot graph for Actual rainfall v/s date for all districts"""
        if 'Dates' in self.dataframe.columns and 'ACTUAL' in self.dataframe.columns and 'district' in self.dataframe.columns:
            # Update the format string to match the actual date format in your data
            self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'], format='%d-%b-%Y')

            plt.figure(figsize=(14, 7))

            for district in self.dataframe['district'].unique():
                district_data = self.dataframe[self.dataframe['district'] == district]
                plt.plot(district_data['Dates'], district_data['ACTUAL'], label=f'Actual Rainfall - {district}', linestyle='-')

            plt.title('Monthly Rainfall in Districts (ACTUAL)')
            plt.xlabel('Date')
            plt.ylabel('Rainfall (mm)')
            plt.legend()
            plt.grid(True)
            plt.xticks(rotation=45)
            plt.show()

        else:
            print("Column(s) not found in the dataframe")

    def prepare_lstm_data(self, seq_length=3):
        """Prepare data for LSTM model"""
        self.dataframe['Dates'] = pd.to_datetime(self.dataframe['Dates'])
        self.dataframe['Year'] = self.dataframe['Dates'].dt.year
        self.dataframe['Month'] = self.dataframe['Dates'].dt.month

        features = self.dataframe[['Year', 'Month', 'NORMAL', 'ACTUAL']]
        features_scaled = self.scaler.fit_transform(features)

        def create_sequences(data, seq_length):
            xs, ys = [], []
            for i in range(len(data) - seq_length):
                x = data[i:i + seq_length]
                y = data[i + seq_length][3]
                xs.append(x)
                ys.append(y)
            return np.array(xs), np.array(ys)

        self.X, self.y = create_sequences(features_scaled, seq_length)
        print("Shape of X:", self.X.shape)
        print("Shape of y:", self.y.shape)

    def build_lstm_model(self):
        """Build LSTM model"""
        self.model = Sequential()
        self.model.add(LSTM(50, return_sequences=True, input_shape=(self.X.shape[1], self.X.shape[2])))
        self.model.add(LSTM(50, return_sequences=False))
        self.model.add(Dense(25))
        self.model.add(Dense(1))

        self.model.compile(optimizer='adam', loss='mean_squared_error')
        self.model.summary()

    def train_lstm_model(self, epochs=50, batch_size=1):
        """Train LSTM model"""
        train_size = int(len(self.X) * 0.8)
        self.X_train, self.X_test = self.X[:train_size], self.X[train_size:]
        self.y_train, self.y_test = self.y[:train_size], self.y[train_size:]

        self.history = self.model.fit(self.X_train, self.y_train, epochs=epochs, batch_size=batch_size, validation_data=(self.X_test, self.y_test))

        plt.plot(self.history.history['loss'])
        plt.plot(self.history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper right')
        plt.show()

    def evaluate_lstm_model(self):
        """Evaluate LSTM model"""
        y_pred = self.model.predict(self.X_test)

        y_test_scaled = self.scaler.inverse_transform(np.concatenate((np.zeros((self.y_test.shape[0], 3)), self.y_test.reshape(-1, 1)), axis=1))[:, 3]
        y_pred_scaled = self.scaler.inverse_transform(np.concatenate((np.zeros((y_pred.shape[0], 3)), y_pred), axis=1))[:, 3]

        rmse = np.sqrt(np.mean((y_test_scaled - y_pred_scaled) ** 2))
        print('Root Mean Squared Error:', rmse)

        plt.plot(y_test_scaled, label='True Value')
        plt.plot(y_pred_scaled, label='Predicted Value')
        plt.title('Predictions vs True Values')
        plt.xlabel('Time Step')
        plt.ylabel('ACTUAL')
        plt.legend()
        plt.show()

# %%
data = Data()

# %%
data.read('Odisha Rainfall day-wise.csv')

# %%
df = data.print_head()
# Out:
#          Dates  NORMAL  ACTUAL district
# 0  01-Mar-2019     0.8    0.29   Anugul
# 1  02-Mar-2019     1.8    0.00   Anugul
# 2  03-Mar-2019     1.6    0.00   Anugul
# 3  04-Mar-2019     0.7    0.07   Anugul
# 4  05-Mar-2019     0.5    0.13   Anugul

# %%
data.print_description()
# Out:
#              NORMAL        ACTUAL
# count  16119.000000  16119.000000
# mean       3.989826      4.200973
# std        4.876777     11.964816
# min        0.000000      0.000000
# 25%        0.400000      0.000000
# 50%        1.500000      0.000000
# 75%        7.000000      3.070000
# max       28.000000    372.530000

# %%
data.normalization()

# %%
data.visualize_NORMAL()

# %%
data.visualize_ACTUAL()

# %%
data.prepare_lstm_data(seq_length=3)
# Out:
# Shape of X: (16116, 3, 4)
# Shape of y: (16116,)

# %%
data.build_lstm_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 50)             11000
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 32501 (126.96 KB)
# Trainable params: 32501 (126.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
data.train_lstm_model(epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.2462e-04 - val_loss: 5.2319e-04
# Epoch 2/100
# 202/202 [==============================] - 3s 17ms/step - loss: 8.2192e-04 - val_loss: 5.2389e-04
# Epoch 3/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.2149e-04 - val_loss: 5.3123e-04
# Epoch 4/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.2087e-04 - val_loss: 5.3342e-04
# Epoch 5/100
# 202/202 [==============================] - 2s 12ms/step - loss: 8.2202e-04 - val_loss: 5.3047e-04
# Epoch 6/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.2001e-04 - val_loss: 5.3418e-04
# Epoch 7/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.1823e-04 - val_loss: 5.5196e-04
# Epoch 8/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.2324e-04 - val_loss: 5.4550e-04
# Epoch 9/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.2339e-04 - val_loss: 5.3472e-04
# Epoch 10/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.2157e-04 - val_loss: 5.3017e-04
# Epoch 11/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.2288e-04 - val_loss: 5.3115e-04
# Epoch 12/100
# 202/202 [==============================] - 3s 13ms/step - loss: 8.2363e-04 - val_loss: 5.3211e-04
# Epoch 13/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.1589e-04 - val_loss: 5.3887e-04
# Epoch 14/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.2117e-04 - val_loss: 5.3901e-04
# Epoch 15/100
# 202/202 [==============================] - 2s 12ms/step - loss: 8.1747e-04 - val_loss: 5.3086e-04
# Epoch 16/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.2174e-04 - val_loss: 5.3322e-04
# Epoch 17/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.1875e-04 - val_loss: 5.3845e-04
# Epoch 18/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.1417e-04 - val_loss: 5.3656e-04
# Epoch 19/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.1989e-04 - val_loss: 5.4116e-04
# Epoch 20/100
# 202/202 [==============================] - 3s 15ms/step - loss: 8.1370e-04 - val_loss: 5.3424e-04
# Epoch 21/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.1216e-04 - val_loss: 5.3150e-04
# Epoch 22/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.2006e-04 - val_loss: 5.4003e-04
# Epoch 23/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.1487e-04 - val_loss: 5.3364e-04
# Epoch 24/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.1359e-04 - val_loss: 5.2970e-04
# Epoch 25/100
# 202/202 [==============================] - 2s 8ms/step - loss: 8.1420e-04 - val_loss: 5.4343e-04
# Epoch 26/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.1132e-04 - val_loss: 5.4164e-04
# Epoch 27/100
# 202/202 [==============================] - 3s 13ms/step - loss: 8.1046e-04 - val_loss: 5.4341e-04
# Epoch 28/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.1083e-04 - val_loss: 5.3653e-04
# Epoch 29/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.0755e-04 - val_loss: 5.5922e-04
# Epoch 30/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.1258e-04 - val_loss: 5.3791e-04
# Epoch 31/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.1024e-04 - val_loss: 5.4920e-04
# Epoch 32/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.1160e-04 - val_loss: 5.4667e-04
# Epoch 33/100
# 202/202 [==============================] - 3s 15ms/step - loss: 8.0805e-04 - val_loss: 5.3741e-04
# Epoch 34/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.0948e-04 - val_loss: 5.3766e-04
# Epoch 35/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.0295e-04 - val_loss: 5.4651e-04
# Epoch 36/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.0490e-04 - val_loss: 5.4805e-04
# Epoch 37/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.0330e-04 - val_loss: 5.4817e-04
# Epoch 38/100
# 202/202 [==============================] - 4s 21ms/step - loss: 8.0552e-04 - val_loss: 5.4535e-04
# Epoch 39/100
# 202/202 [==============================] - 3s 16ms/step - loss: 8.1094e-04 - val_loss: 5.3986e-04
# Epoch 40/100
# 202/202 [==============================] - 3s 17ms/step - loss: 8.0183e-04 - val_loss: 5.5180e-04
# Epoch 41/100
# 202/202 [==============================] - 2s 11ms/step - loss: 8.0450e-04 - val_loss: 5.4659e-04
# Epoch 42/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.0297e-04 - val_loss: 5.4231e-04
# Epoch 43/100
# 202/202 [==============================] - 3s 14ms/step - loss: 8.0217e-04 - val_loss: 5.4612e-04
# Epoch 44/100
# 202/202 [==============================] - 3s 16ms/step - loss: 7.9950e-04 - val_loss: 5.4754e-04
# Epoch 45/100
# 202/202 [==============================] - 2s 9ms/step - loss: 8.0142e-04 - val_loss: 5.4768e-04
# Epoch 46/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.9304e-04 - val_loss: 5.6039e-04
# Epoch 47/100
# 202/202 [==============================] - 2s 10ms/step - loss: 8.0212e-04 - val_loss: 5.5020e-04
# Epoch 48/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.9905e-04 - val_loss: 5.4628e-04
# Epoch 49/100
# 202/202 [==============================] - 3s 16ms/step - loss: 7.9524e-04 - val_loss: 5.5196e-04
# Epoch 50/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.9183e-04 - val_loss: 5.5150e-04
# Epoch 51/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.8429e-04 - val_loss: 5.5441e-04
# Epoch 52/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.8391e-04 - val_loss: 5.5404e-04
# Epoch 53/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.9060e-04 - val_loss: 5.6679e-04
# Epoch 54/100
# 202/202 [==============================] - 2s 12ms/step - loss: 7.7952e-04 - val_loss: 5.6120e-04
# Epoch 55/100
# 202/202 [==============================] - 4s 19ms/step - loss: 7.7997e-04 - val_loss: 6.2305e-04
# Epoch 56/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.8413e-04 - val_loss: 5.5457e-04
# Epoch 57/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.8779e-04 - val_loss: 5.5360e-04
# Epoch 58/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.8109e-04 - val_loss: 5.5898e-04
# Epoch 59/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.7999e-04 - val_loss: 5.5871e-04
# Epoch 60/100
# 202/202 [==============================] - 3s 17ms/step - loss: 7.7028e-04 - val_loss: 5.5638e-04
# Epoch 61/100
# 202/202 [==============================] - 4s 19ms/step - loss: 7.7683e-04 - val_loss: 5.6309e-04
# Epoch 62/100
# 202/202 [==============================] - 3s 14ms/step - loss: 7.7220e-04 - val_loss: 5.9480e-04
# Epoch 63/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.8184e-04 - val_loss: 5.7788e-04
# Epoch 64/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.7063e-04 - val_loss: 5.5968e-04
# Epoch 65/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.7358e-04 - val_loss: 5.8677e-04
# Epoch 66/100
# 202/202 [==============================] - 3s 14ms/step - loss: 7.6791e-04 - val_loss: 5.7086e-04
# Epoch 67/100
# 202/202 [==============================] - 3s 15ms/step - loss: 7.6959e-04 - val_loss: 6.1647e-04
# Epoch 68/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.7097e-04 - val_loss: 5.8293e-04
# Epoch 69/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.7200e-04 - val_loss: 5.6164e-04
# Epoch 70/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.7184e-04 - val_loss: 5.6100e-04
# Epoch 71/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.5848e-04 - val_loss: 5.7086e-04
# Epoch 72/100
# 202/202 [==============================] - 3s 13ms/step - loss: 7.6347e-04 - val_loss: 6.1151e-04
# Epoch 73/100
# 202/202 [==============================] - 3s 14ms/step - loss: 7.6679e-04 - val_loss: 6.0346e-04
# Epoch 74/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.7319e-04 - val_loss: 5.7495e-04
# Epoch 75/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.6737e-04 - val_loss: 5.9641e-04
# Epoch 76/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.6815e-04 - val_loss: 5.7166e-04
# Epoch 77/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.5110e-04 - val_loss: 5.5955e-04
# Epoch 78/100
# 202/202 [==============================] - 3s 13ms/step - loss: 7.5512e-04 - val_loss: 6.1404e-04
# Epoch 79/100
# 202/202 [==============================] - 3s 16ms/step - loss: 7.6040e-04 - val_loss: 5.8118e-04
# Epoch 80/100
# 202/202 [==============================] - 2s 12ms/step - loss: 7.6112e-04 - val_loss: 5.8657e-04
# Epoch 81/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.6185e-04 - val_loss: 5.7226e-04
# Epoch 82/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.6813e-04 - val_loss: 5.7288e-04
# Epoch 83/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.5425e-04 - val_loss: 5.7743e-04
# Epoch 84/100
# 202/202 [==============================] - 3s 14ms/step - loss: 7.5505e-04 - val_loss: 5.8861e-04
# Epoch 85/100
# 202/202 [==============================] - 3s 15ms/step - loss: 7.5009e-04 - val_loss: 5.8106e-04
# Epoch 86/100
# 202/202 [==============================] - 2s 10ms/step - loss: 7.5851e-04 - val_loss: 5.8137e-04
# Epoch 87/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.5171e-04 - val_loss: 5.7193e-04
# Epoch 88/100
# 202/202 [==============================] - 2s 12ms/step - loss: 7.4927e-04 - val_loss: 5.8206e-04
# Epoch 89/100
# 202/202 [==============================] - 3s 13ms/step - loss: 7.4748e-04 - val_loss: 5.7563e-04
# Epoch 90/100
# 202/202 [==============================] - 4s 18ms/step - loss: 7.5468e-04 - val_loss: 5.7113e-04
# Epoch 91/100
# 202/202 [==============================] - 2s 8ms/step - loss: 7.4539e-04 - val_loss: 5.6998e-04
# Epoch 92/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.4928e-04 - val_loss: 5.9506e-04
# Epoch 93/100
# 202/202 [==============================] - 3s 13ms/step - loss: 7.4752e-04 - val_loss: 5.8956e-04
# Epoch 94/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.3975e-04 - val_loss: 6.0368e-04
# Epoch 95/100
# 202/202 [==============================] - 3s 13ms/step - loss: 7.4731e-04 - val_loss: 5.7029e-04
# Epoch 96/100
# 202/202 [==============================] - 3s 15ms/step - loss: 7.3681e-04 - val_loss: 5.9090e-04
# Epoch 97/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.3535e-04 - val_loss: 5.9574e-04
# Epoch 98/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.4033e-04 - val_loss: 5.9212e-04
# Epoch 99/100
# 202/202 [==============================] - 2s 9ms/step - loss: 7.3100e-04 - val_loss: 5.9366e-04
# Epoch 100/100
# 202/202 [==============================] - 2s 11ms/step - loss: 7.2492e-04 - val_loss: 5.6801e-04

# %%
data.evaluate_lstm_model()
# Out:
# 101/101 [==============================] - 3s 8ms/step
# Root Mean Squared Error: 0.023833041953705284
